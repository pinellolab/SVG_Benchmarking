# %%
import numpy as np
import pandas as pd
import scipy as sp
import scanpy as sc
import squidpy as sq
import anndata as ad
import seaborn as sns
import matplotlib.pyplot as plt
from anndata import AnnData

# %%
adata = sc.read_h5ad('./scDesign3/svg_50.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2696 × 995
#     obs: 'cells'
#     var: 'spatially_variable'
#     uns: 'log1p', 'spatial'
#     obsm: 'spatial'
#     layers: 'counts'

# %%
sq.pl.spatial_scatter(adata, color=['Ttr', 'S100a5', 'Prr32', 'Omp', 'Penk'], shape=None, frameon=False, size=35, ncols=5)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
sq.pl.spatial_scatter(adata, color=['Ttr', 'S100a5', 'Prr32', 'Omp', 'Penk'], shape=None, frameon=False, size=35, ncols=5)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
