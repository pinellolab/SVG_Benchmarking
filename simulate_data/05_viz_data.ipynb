# %%
import numpy as np
import pandas as pd
import scipy as sp
import scanpy as sc
import squidpy as sq
import anndata as ad
import simstpy as sim
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad('./Clustering/breast_tumor_logfc_1.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 5463 × 200
#     obs: 'spatial_cluster', 'obs_ids', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts'
#     var: 'spatially_variable', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'log1p', 'spatial', 'spatial_cluster_colors'
#     obsm: 'spatial'
#     layers: 'counts'

# %%
adata = sc.read_h5ad(f"./Clustering/mouse_cerebellum_logfc_2.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 20982 × 200
#     obs: 'spatial_cluster', 'obs_ids', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts'
#     var: 'spatially_variable', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'log1p', 'spatial', 'spatial_cluster_colors'
#     obsm: 'spatial'
#     layers: 'counts'

# %%
sq.pl.spatial_scatter(adata, shape=None, color=adata.var_names[adata.var.spatially_variable][1], frameon=False,
                      dpi=120, size=1)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
sq.pl.spatial_scatter(adata, shape=None, color=adata.var_names[~adata.var.spatially_variable][1], frameon=False,
                      dpi=120, size=1)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
